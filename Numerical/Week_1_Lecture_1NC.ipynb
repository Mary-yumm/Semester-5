# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: brown;">CS 2008: Numerical Computing</h2>
# </div>
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - Recommended Book?
# - Evaluations in course
# - - Quizzes & assignments etc
# - - Exams
# - Learning journey in this course

# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: brown;">CS 2008: Numerical Computing</h2>
# </div>
#
# <div style="text-align: center;">
#     <h4 style="color: gray;">Textbook: Computational Mathematics: An introduction to Numerical Analysis and Scientific Computing with Python, Chapman and Hall/CRC, Dimitrios Mitsotakis </h4>
#
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: brown;">CS 2008: Numerical Computing</h2>
# </div>
#
#
# <div style="text-align: center;">
#     <h4 style="color: gray;">Programming language: <span style="color:green">Python</span> </h4>
#     <h4 style="color: gray;">Libraries: <span style="color:green">NumPy, SciPy & plotting libraries i.e matplotlib</span> </h4>
#
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: brown;">CS 2008: Numerical Computing</h2>
# </div>
#
# <div style="text-align: center;">
#     <h2 style="color: green;">About the code editors</h2>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: brown;">CS 2008: Numerical Computing</h2>
# </div>
#
# <div style="text-align: center;">
#     <h2 style="color: gray;">- Regarding attendance, exams & other evaluations i.e quizes and assignments</h2></div>
#
# <div style="text-align: left;">
#     <h4 style="color: gray;">Retake of missed assessment items (other than sessional/ final exam) will not be held. Student who misses an assessment item (other than sessional / final exam) is awarded zero marks in that assessment item, i.e., late submission will not be accepted.</h4></div>

# %% [markdown]
# **NOTE**<div style="text-align: center;">
#     <h4 style="color: red;">Attendance will be marked at the start of class. No changes will be made afterward</h4></div>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: brown;">CS 2008: Numerical Computing</h2>
# </div>
#
# <div style="text-align: center;">
#     - <h2 style="color: green;">Learning Journey in this course</h2>
# </div>

# %% [markdown]
# **Learning Journey in this course**

# %% [markdown]
# <img src="NC5.png" alt="Vector Image" style="width:100%; height:100%;"/>

# %% [markdown]
# # we'll cover today
#
# - Basics
# - Some important data structures of python
# - Control statments
# - Classes in python & some other stuff

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Basic Python**
# -  variables
# -  Basic mathematical operations
# -  Mathematical functions and constants
# -  Powers of 10 and scientific notation
# -  Assignment Operators

# %%
# Out:
# 0.2

# %%
section_c={
 'st1':[4,4,4,4,4,4,4,4,4],
 'st2': 'ziad'     
}
section_c['st1']
# Out:
# [4, 4, 4, 4, 4, 4, 4, 4, 4]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Basics of Python (cont...)
# - <span style="color:red">**Operator Precedence**</span>
# - **+**,**-**,**\***, **/**, **//**, **\****, **%**
# -------
# - - ()
# - - \*\*
# - -  \*\/
# - - +-

# %% [markdown]
# **Important data structures of python**
# - - Strings
# - - Tuples
# - - Dictionaries
# - - Lists
# - - - Lists of lists

# %%
name='abc'
name[0]='A'
# Out:
# ----------------------------------------------------------------
# TypeError                      Traceback (most recent call last)
# Cell In[31], line 2
#       1 name='abc'
# ----> 2 name[0]='A'
#
# TypeError: 'str' object does not support item assignment

# %%
set1= {1,2,3,4,5}
set2= {1,2,3,77,99}

# %%
print(set1)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### Control statments
#  **Flow Control**
# -  for loops
# -  Boolean type of variables
# -  while loops
# -  Decisions and the if statement
# -  The command break

# %%
i=3
stop_button=True
while i<10 and stop_button:
    print(i)
    i=i+1
    if i==7:
        stop_button=False
# Out:
# 3
# 4
# 5
# 6

# %%
i=1
button=True
while i<10 and button:
    print(i)
    i=i+1
    if i==3:
        
        print('reached to his limit')
        button=False
# Out:
# 1
# 2
# reached to his limit

# %% [markdown]
# ### Classes in python & some other stuff
# - Functions
# - Classes

# %%
def add1(a,b):
    return a+b
 
add2=lambda a,b:a+b

print(add1(3,5))
print(add2(3,5))
# Out:
# 8
# 8

# %%
a=3
b=2
c=4
def multi(func, c):
    return func(a, b) * c

result = multi(lambda a, b: a + b, c)
print(result)
# Out:
# 20

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.__age=age

    
st1=Student('shayan')
st2=Student('raza')

# %%
st1.
# Out:
# 'shayan'

# %%
st2.name
# Out:
# 'raza'

# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: green;">Next we'll cover</h2>
# </div>

# %% [markdown]
# [Also explore this link as well](https://github.com/dmitsot/computational_mathematics/blob/main/Chapter1.ipynb)

# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: green;">Summary & Your home work for today</h1> </div>
# <div>
#     <div style="text-align: center;">
#     <h3 style="color: brown;">Book Chapter 1</h3></div>
#
# ![image-3.png](attachment:image-3.png)
# <div style="text-align: center;">
#     <h3 style="color: brown;">2) Do some practice work on exercise of this chapter</h3></div>
